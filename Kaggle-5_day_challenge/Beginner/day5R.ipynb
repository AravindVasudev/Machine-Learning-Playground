# %%
library(tidyverse)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.2.1 ──
# ✔ ggplot2 2.2.1.9000     ✔ purrr   0.2.4
# ✔ tibble  1.3.4          ✔ dplyr   0.7.4
# ✔ tidyr   0.7.2          ✔ stringr 1.2.0
# ✔ readr   1.1.1.9000     ✔ forcats 0.2.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
# read the dataset
data <- read_csv("../input/CAERS_ASCII_2004_2017Q2.csv")

head(data)
summary(data)
# Out:
# Parsed with column specification:
# cols(
#   `RA_Report #` = col_double(),
#   `RA_CAERS Created Date` = col_character(),
#   `AEC_Event Start Date` = col_character(),
#   `PRI_Product Role` = col_character(),
#   `PRI_Reported Brand/Product Name` = col_character(),
#   `PRI_FDA Industry Code` = col_double(),
#   `PRI_FDA Industry Name` = col_character(),
#   `CI_Age at Adverse Event` = col_double(),
#   `CI_Age Unit` = col_character(),
#   CI_Gender = col_character(),
#   `AEC_One Row Outcomes` = col_character(),
#   `SYM_One Row Coded Symptoms` = col_character()
# )
#   RA_Report # RA_CAERS Created Date AEC_Event Start Date PRI_Product Role
# 1 65325       1/1/2004              8/4/2003             Suspect
# 2 65325       1/1/2004              8/4/2003             Suspect
# 3 65333       1/1/2004              NA                   Suspect
# 4 65335       1/1/2004              11/24/2003           Suspect
# 5 65336       1/1/2004              NA                   Suspect
# 6 65345       1/1/2004              12/21/2003           Suspect
#   PRI_Reported Brand/Product Name                        PRI_FDA Industry Code
# 1 MIDWEST COUNTRY FAIR CHOCOLATE FLAVORED CHIPS           3
# 2 MIDWEST COUNTRY FAIR CHOCOLATE FLAVORED CHIPS           3
# 3 KROGER CLASSIC CREAM-DE-MINT CANDY MINT CHIP ICE CREAM 13
# 4 ENFAMIL LIPIL BABY FORMULA                             40
# 5 ENFIMIL LIPIL BABY FORMULA                             40
# 6 FRITO LAY FUNYUNS ONION FLAVOR, ONION RINGS             7
#   PRI_FDA Industry Name       CI_Age at Adverse Event CI_Age Unit
# 1 Bakery Prod/Dough/Mix/Icing  2                      Year(s)
# 2 Bakery Prod/Dough/Mix/Icing  2                      Year(s)
# 3 Ice Cream Prod              NA                      Not Available
# 4 Baby Food Prod               3                      Month(s)
# 5 Baby Food Prod              NA                      Not Available
# 6 Snack Food Item             10                      Year(s)
#   CI_Gender
# 1 Female
# 2 Female
# 3 Female
# 4 Not Available
# 5 Not Available
# 6 Male
#   AEC_One Row Outcomes
# 1 VISITED AN ER, VISITED A HEALTH CARE PROVIDER, REQ. INTERVENTION TO PRVNT PERM. IMPRMNT., HOSPITALIZATION
# 2 VISITED AN ER, VISITED A HEALTH CARE PROVIDER, REQ. INTERVENTION TO PRVNT PERM. IMPRMNT., HOSPITALIZATION
# 3 VISITED AN ER
# 4 NON-SERIOUS INJURIES/ ILLNESS
# 5 VISITED A HEALTH CARE PROVIDER
# 6 NON-SERIOUS INJURIES/ ILLNESS
#   SYM_One Row Coded Symptoms
# 1 SWELLING FACE, RASH, WHEEZING, COUGH, HOSPITALISATION, DYSPNOEA
# 2 SWELLING FACE, WHEEZING, COUGH, RASH, HOSPITALISATION, DYSPNOEA
# 3 NAUSEA, DYSGEUSIA, DIARRHOEA
# 4 GASTROINTESTINAL DISORDER, VOMITING
# 5 GASTROINTESTINAL DISORDER, PHYSICAL EXAMINATION
# 6 CHOKING
#   RA_Report #     RA_CAERS Created Date AEC_Event Start Date PRI_Product Role
#  Min.   : 65325   Length:90786          Length:90786         Length:90786
#  1st Qu.:125985   Class :character      Class :character     Class :character
#  Median :168433   Mode  :character      Mode  :character     Mode  :character
#  Mean   :156578
#  3rd Qu.:190411
#  Max.   :214610
#
#  PRI_Reported Brand/Product Name PRI_FDA Industry Code PRI_FDA Industry Name
#  Length:90786                    Min.   : 2.00         Length:90786
#  Class :character                1st Qu.:29.00         Class :character
#  Mode  :character                Median :54.00         Mode  :character
#                                  Mean   :43.06
#                                  3rd Qu.:54.00
#                                  Max.   :54.00
#
#  CI_Age at Adverse Event CI_Age Unit         CI_Gender
#  Min.   :  0.00          Length:90786       Length:90786
#  1st Qu.: 35.00          Class :character   Class :character
#  Median : 53.00          Mode  :character   Mode  :character
#  Mean   : 50.76
#  3rd Qu.: 68.00
#  Max.   :736.00
#  NA's   :37860
#  AEC_One Row Outcomes SYM_One Row Coded Symptoms
#  Length:90786         Length:90786
#  Class :character     Class :character
#  Mode  :character     Mode  :character

# %%
data <- data %>% filter(CI_Gender %in% list("Male", "Female"))
sex <- table(data$CI_Gender)
sex
# Out:
# Female   Male
#  58924  26943

# %%
chisq.test(sex)
# Out:
# 	Chi-squared test for given probabilities
#
# data:  sex
# X-squared = 11911, df = 1, p-value < 2.2e-16

# %%
data %>%
    ggplot(aes(CI_Gender, fill=CI_Gender)) +
    geom_bar()
